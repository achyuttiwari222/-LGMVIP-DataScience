# %% [markdown]
# ## Data Science Intern - LetsGrowMore
#
# ## Author : Achyut Tiwari
#
# ## Iris Flowers Classification ML Project :
#
# This particular ML project is usually referred to as the “Hello World” of Machine Learning. The iris flowers dataset contains numeric attributes, and it is perfect for beginners to learn about supervised ML algorithms, mainly how to load and handle data. Also, since this is a small dataset, it can easily fit in memory without requiring special transformations or scaling capabilities.
#
#
# TASK :
# ## To Predict the species of the iris flower.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp
import os

# %%
dataset = pd.read_csv('http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data')

# %%
dataset.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
dataset.shape
# Out:
# (149, 5)

# %%
dataset.columns
# Out:
# Index(['5.1', '3.5', '1.4', '0.2', 'Iris-setosa'], dtype='object')

# %%
dataset.columns=(['SepalLength','SepalWidth','PetalLength', 'PetalWidth','Species'])

# %%
dataset.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          4.9         3.0          1.4         0.2  Iris-setosa
# 1          4.7         3.2          1.3         0.2  Iris-setosa
# 2          4.6         3.1          1.5         0.2  Iris-setosa
# 3          5.0         3.6          1.4         0.2  Iris-setosa
# 4          5.4         3.9          1.7         0.4  Iris-setosa

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  149 non-null    float64
#  1   SepalWidth   149 non-null    float64
#  2   PetalLength  149 non-null    float64
#  3   PetalWidth   149 non-null    float64
#  4   Species      149 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %%
dataset.count()
# Out:
# SepalLength    149
# SepalWidth     149
# PetalLength    149
# PetalWidth     149
# Species        149
# dtype: int64

# %%
dataset.describe()
# Out:
#        SepalLength  SepalWidth  PetalLength  PetalWidth
# count   149.000000  149.000000   149.000000  149.000000
# mean      5.848322    3.051007     3.774497    1.205369
# std       0.828594    0.433499     1.759651    0.761292
# min       4.300000    2.000000     1.000000    0.100000
# 25%       5.100000    2.800000     1.600000    0.300000
# 50%       5.800000    3.000000     4.400000    1.300000
# 75%       6.400000    3.300000     5.100000    1.800000
# max       7.900000    4.400000     6.900000    2.500000

# %%
dataset.value_counts
# Out:
# <bound method DataFrame.value_counts of      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            4.9         3.0          1.4         0.2     Iris-setosa
# 1            4.7         3.2          1.3         0.2     Iris-setosa
# 2            4.6         3.1          1.5         0.2     Iris-setosa
# 3            5.0         3.6          1.4         0.2     Iris-setosa
# 4            5.4         3.9          1.7         0.4     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 144          6.7         3.0          5.2         2.3  Iris-virginica
# 145          6.3         2.5          5.0         1.9  Iris-virginica
# 146          6.5         3.0          5.2         2.0  Iris-virginica
# 147          6.2         3.4          5.4         2.3  Iris-virginica
# 148          5.9         3.0          5.1         1.8  Iris-virginica
#
# [149 rows x 5 columns]>

# %%
dataset.tail()
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 144          6.7         3.0          5.2         2.3  Iris-virginica
# 145          6.3         2.5          5.0         1.9  Iris-virginica
# 146          6.5         3.0          5.2         2.0  Iris-virginica
# 147          6.2         3.4          5.4         2.3  Iris-virginica
# 148          5.9         3.0          5.1         1.8  Iris-virginica

# %%
dataset.plot(kind="scatter", x="SepalLength",color='#52b920', y= "SepalWidth")
# Out:
# <AxesSubplot:xlabel='SepalLength', ylabel='SepalWidth'>

# %%
dataset.plot(kind="hist", x="SepalLength",color='orange', y= "SepalWidth")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
dataset.plot(kind="area", x="SepalLength", y= "SepalWidth")
# Out:
# <AxesSubplot:xlabel='SepalLength'>

# %%
dataset.plot(kind="bar", x="SepalLength", y= "SepalWidth")
# Out:
# <AxesSubplot:xlabel='SepalLength'>

# %% [markdown]
# #JOINT PLOT:

# %%
sns.jointplot( data=dataset,x="SepalLength", y="SepalWidth",color='black', size=5)
# Out:
# C:\Users\achyut\anaconda3\lib\site-packages\seaborn\axisgrid.py:2073: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#DENSITY PLOT : KDE
sns.kdeplot(data= dataset, x="SepalLength", y="SepalWidth",color='red', size=5)
# Out:
# C:\Users\achyut\anaconda3\lib\site-packages\seaborn\distributions.py:1182: UserWarning: The following kwargs were not used by contour: 'size'
#   cset = contour_func(
# <AxesSubplot:xlabel='SepalLength', ylabel='SepalWidth'>

# %%
#DATA VISUALIZATION USING BAR
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.barplot(x = 'Species', y = 'SepalLength', data = dataset, palette="cubehelix")
plt.subplot(2,2,2)
sns.barplot(x = 'Species', y = 'SepalWidth', data = dataset, palette="Oranges")
plt.subplot(2,2,3)
sns.barplot(x = 'Species', y = 'PetalLength', data = dataset, palette="Oranges")
plt.subplot(2,2,4)
sns.barplot(x = 'Species', y = 'PetalWidth', data = dataset, palette="cubehelix")
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidth'>

# %%
plt.figure(figsize=(20,15))
plt.subplot(2,2,1)
sns.distplot(dataset['SepalLength'], color="#DE3163").set_title('SepalLength Interval')
plt.subplot(2,2,2)
sns.distplot(dataset['SepalWidth'], color="#ff8000").set_title('SepalWidth Interval')
plt.subplot(2,2,3)
sns.distplot(dataset['PetalLength'], color="#1a0000").set_title('PetalLength Interval')
plt.subplot(2,2,4)
sns.distplot(dataset['PetalWidth'], color="#4d0000").set_title('PetalWidth Interval')
# Out:
# C:\Users\achyut\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\achyut\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
#TRAINING AND TESTING DATA
x = dataset.drop(columns="Species")
y = dataset["Species"]
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=0,test_size=0.2)

# %%
print(len(x_train))
print(len(x_test))
print(len(y_train))
print(len(y_test))
# Out:
# 119
# 30
# 119
# 30

# %% [markdown]
# MODELS :

# %%
# KNeighborsClassifier

from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=7)

knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=7)

# %%
y_pred=knn.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Accuracy of Model:\n",knn.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       1.00      1.00      1.00        10
#  Iris-virginica       1.00      1.00      1.00         8
#
#        accuracy                           1.00        30
#       macro avg       1.00      1.00      1.00        30
#    weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
#  [[12  0  0]
#  [ 0 10  0]
#  [ 0  0  8]]
# Accuracy of Model:
#  97.47899159663865

# %% [markdown]
# ## KNeighborsClassifier model gives the good accuracy score of approx 98%

# %%
#Random Forest Classifier

from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=rfc.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Training Score:\n",rfc.score(x_train,y_train)*100)
accuracy_score(y_test,y_pred)
# Out:
# Classification Report is:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.77      1.00      0.87        10
#  Iris-virginica       1.00      0.62      0.77         8
#
#        accuracy                           0.90        30
#       macro avg       0.92      0.88      0.88        30
#    weighted avg       0.92      0.90      0.89        30
#
# Confusion Matrix:
#  [[12  0  0]
#  [ 0 10  0]
#  [ 0  3  5]]
# Training Score:
#  100.0
# 0.9

# %% [markdown]
#  ## Random Forest Classifier model gives the best accuracy score of 100%

# %%
#Naive Bayes

from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
gnb.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
y_pred=gnb.predict(x_test)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("Classification Report is:\n",classification_report(y_test,y_pred))
print("Confusion Matrix:\n",confusion_matrix(y_test,y_pred))
print("Accuracy of Model:\n",gnb.score(x_train,y_train)*100)
# Out:
# Classification Report is:
#                   precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00        12
# Iris-versicolor       0.77      1.00      0.87        10
#  Iris-virginica       1.00      0.62      0.77         8
#
#        accuracy                           0.90        30
#       macro avg       0.92      0.88      0.88        30
#    weighted avg       0.92      0.90      0.89        30
#
# Confusion Matrix:
#  [[12  0  0]
#  [ 0 10  0]
#  [ 0  3  5]]
# Accuracy of Model:
#  97.47899159663865

# %% [markdown]
# ## Naive Bayes model gives the good accuracy score of approx 98%

# %% [markdown]
# ## Conclusion : We got a good accuracy score of about 99 % using various algorithms.
